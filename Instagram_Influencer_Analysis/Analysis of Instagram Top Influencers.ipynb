# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("top_insta_influencers_data.csv")
data
# Out:
#      rank channel_info  influence_score  posts followers avg_likes  \
# 0       1    cristiano               92   3.3k    475.8m      8.7m
# 1       2  kyliejenner               91   6.9k    366.2m      8.3m
# 2       3     leomessi               90  0.89k    357.3m      6.8m
# 3       4  selenagomez               93   1.8k    342.7m      6.2m
# 4       5      therock               91   6.8k    334.1m      1.9m
# ..    ...          ...              ...    ...       ...       ...
# 195   196    iambeckyg               71   2.3k     33.2m    623.8k
# 196   197   nancyajram               81   3.8k     33.2m    390.4k
# 197   198  luansantana               79  0.77k     33.2m    193.3k
# 198   199    nickjonas               78   2.3k     33.0m    719.6k
# 199   200    raisa6690               80   4.2k     32.8m    232.2k
#
#     60_day_eng_rate new_post_avg_like total_likes        country
# 0             1.39%              6.5m       29.0b          Spain
# 1             1.62%              5.9m       57.4b  United States
# 2             1.24%              4.4m        6.0b            NaN
# 3             0.97%              3.3m       11.5b  United States
# 4             0.20%            665.3k       12.5b  United States
# ..              ...               ...         ...            ...
# 195           1.40%            464.7k        1.4b  United States
# 196           0.64%            208.0k        1.5b         France
# 197           0.26%             82.6k      149.2m         Brazil
# 198           1.42%            467.7k        1.7b  United States
# 199           0.30%             97.4k      969.1m      Indonesia
#
# [200 rows x 10 columns]

# %%
data.head(10)
# Out:
#    rank     channel_info  influence_score  posts followers avg_likes  \
# 0     1        cristiano               92   3.3k    475.8m      8.7m
# 1     2      kyliejenner               91   6.9k    366.2m      8.3m
# 2     3         leomessi               90  0.89k    357.3m      6.8m
# 3     4      selenagomez               93   1.8k    342.7m      6.2m
# 4     5          therock               91   6.8k    334.1m      1.9m
# 5     6    kimkardashian               91   5.6k    329.2m      3.5m
# 6     7     arianagrande               92   5.0k    327.7m      3.7m
# 7     8          beyonce               92   2.0k    272.8m      3.6m
# 8     9  khloekardashian               89   4.1k    268.3m      2.4m
# 9    10     justinbieber               91   7.4k    254.5m      1.9m
#
#   60_day_eng_rate new_post_avg_like total_likes        country
# 0           1.39%              6.5m       29.0b          Spain
# 1           1.62%              5.9m       57.4b  United States
# 2           1.24%              4.4m        6.0b            NaN
# 3           0.97%              3.3m       11.5b  United States
# 4           0.20%            665.3k       12.5b  United States
# 5           0.88%              2.9m       19.9b  United States
# 6           1.20%              3.9m       18.4b  United States
# 7           0.76%              2.0m        7.4b  United States
# 8           0.35%            926.9k        9.8b  United States
# 9           0.59%              1.5m       13.9b         Canada

# %%
data.tail(10)
# Out:
#      rank         channel_info  influence_score  posts followers avg_likes  \
# 190   191                  bmw               79   9.3k     33.7m    231.3k
# 191   192         danbilzerian               84   1.4k     33.6m      2.0m
# 192   193  khabib_nurmagomedov               63   4.5k     33.5m    685.1k
# 193   194               zidane               41  0.37k     33.5m      1.1m
# 194   195          sonamkapoor               75   4.8k     33.3m    264.7k
# 195   196            iambeckyg               71   2.3k     33.2m    623.8k
# 196   197           nancyajram               81   3.8k     33.2m    390.4k
# 197   198          luansantana               79  0.77k     33.2m    193.3k
# 198   199            nickjonas               78   2.3k     33.0m    719.6k
# 199   200            raisa6690               80   4.2k     32.8m    232.2k
#
#     60_day_eng_rate new_post_avg_like total_likes        country
# 190           0.23%             76.5k        2.2b        Germany
# 191           3.58%              1.2m        2.8b         Canada
# 192           0.67%            220.7k        3.1b         Russia
# 193           1.61%            532.7k      391.9m         France
# 194           0.63%            209.2k        1.3b          India
# 195           1.40%            464.7k        1.4b  United States
# 196           0.64%            208.0k        1.5b         France
# 197           0.26%             82.6k      149.2m         Brazil
# 198           1.42%            467.7k        1.7b  United States
# 199           0.30%             97.4k      969.1m      Indonesia

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rank               200 non-null    int64
#  1   channel_info       200 non-null    object
#  2   influence_score    200 non-null    int64
#  3   posts              200 non-null    object
#  4   followers          200 non-null    object
#  5   avg_likes          200 non-null    object
#  6   60_day_eng_rate    200 non-null    object
#  7   new_post_avg_like  200 non-null    object
#  8   total_likes        200 non-null    object
#  9   country            138 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 15.8+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#              rank  influence_score
# count  200.000000       200.000000
# mean   100.500000        81.820000
# std     57.879185         8.878159
# min      1.000000        22.000000
# 25%     50.750000        80.000000
# 50%    100.500000        84.000000
# 75%    150.250000        86.000000
# max    200.000000        93.000000

# %%
data[['rank','total_likes']]
# Out:
#      rank total_likes
# 0       1       29.0b
# 1       2       57.4b
# 2       3        6.0b
# 3       4       11.5b
# 4       5       12.5b
# ..    ...         ...
# 195   196        1.4b
# 196   197        1.5b
# 197   198      149.2m
# 198   199        1.7b
# 199   200      969.1m
#
# [200 rows x 2 columns]

# %%
replace = {'b': 'e9', 'm': 'e6', 'k': 'e3', '%': ''}
convert_column = ['total_likes', 'posts', 'followers', 'avg_likes', '60_day_eng_rate', 'new_post_avg_like']
data[convert_column] = data[convert_column].replace(replace, regex=True).astype(float)
data[convert_column]
# Out:
#       total_likes   posts    followers  avg_likes  60_day_eng_rate  \
# 0    2.900000e+10  3300.0  475800000.0  8700000.0             1.39
# 1    5.740000e+10  6900.0  366200000.0  8300000.0             1.62
# 2    6.000000e+09   890.0  357300000.0  6800000.0             1.24
# 3    1.150000e+10  1800.0  342700000.0  6200000.0             0.97
# 4    1.250000e+10  6800.0  334100000.0  1900000.0             0.20
# ..            ...     ...          ...        ...              ...
# 195  1.400000e+09  2300.0   33200000.0   623800.0             1.40
# 196  1.500000e+09  3800.0   33200000.0   390400.0             0.64
# 197  1.492000e+08   770.0   33200000.0   193300.0             0.26
# 198  1.700000e+09  2300.0   33000000.0   719600.0             1.42
# 199  9.691000e+08  4200.0   32800000.0   232200.0             0.30
#
#      new_post_avg_like
# 0            6500000.0
# 1            5900000.0
# 2            4400000.0
# 3            3300000.0
# 4             665300.0
# ..                 ...
# 195           464700.0
# 196           208000.0
# 197            82600.0
# 198           467700.0
# 199            97400.0
#
# [200 rows x 6 columns]

# %%
data.rename(columns={'channel_info': 'account_name'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rank               200 non-null    int64
#  1   account_name       200 non-null    object
#  2   influence_score    200 non-null    int64
#  3   posts              200 non-null    float64
#  4   followers          200 non-null    float64
#  5   avg_likes          200 non-null    float64
#  6   60_day_eng_rate    199 non-null    float64
#  7   new_post_avg_like  200 non-null    float64
#  8   total_likes        200 non-null    float64
#  9   country            138 non-null    object
# dtypes: float64(6), int64(2), object(2)
# memory usage: 15.8+ KB

# %%
numerical_columns =['influence_score', 'posts', 'followers', 'avg_likes', '60_day_eng_rate', 'new_post_avg_like', 'total_likes']
corr_data = data[numerical_columns].corr()
corr_data
# Out:
#                    influence_score     posts  followers  avg_likes  \
# influence_score           1.000000  0.160068   0.367713   0.051478
# posts                     0.160068  1.000000   0.060398  -0.343087
# followers                 0.367713  0.060398   1.000000   0.349195
# avg_likes                 0.051478 -0.343087   0.349195   1.000000
# 60_day_eng_rate          -0.081891 -0.324068  -0.100905   0.754587
# new_post_avg_like         0.036548 -0.290080   0.300914   0.845978
# total_likes               0.237675  0.233328   0.667539   0.357940
#
#                    60_day_eng_rate  new_post_avg_like  total_likes
# influence_score          -0.081891           0.036548     0.237675
# posts                    -0.324068          -0.290080     0.233328
# followers                -0.100905           0.300914     0.667539
# avg_likes                 0.754587           0.845978     0.357940
# 60_day_eng_rate           1.000000           0.869202    -0.019524
# new_post_avg_like         0.869202           1.000000     0.329326
# total_likes              -0.019524           0.329326     1.000000

# %%
data.sort_values(by='influence_score', inplace=True)
data.tail(10)
# Out:
#     rank   account_name  influence_score   posts    followers  avg_likes  \
# 9     10   justinbieber               91  7400.0  254500000.0  1900000.0
# 13    14    taylorswift               91   530.0  222200000.0  2400000.0
# 1      2    kyliejenner               91  6900.0  366200000.0  8300000.0
# 5      6  kimkardashian               91  5600.0  329200000.0  3500000.0
# 4      5        therock               91  6800.0  334100000.0  1900000.0
# 6      7   arianagrande               92  5000.0  327700000.0  3700000.0
# 20    21      katyperry               92  2000.0  170300000.0   715000.0
# 7      8        beyonce               92  2000.0  272800000.0  3600000.0
# 0      1      cristiano               92  3300.0  475800000.0  8700000.0
# 3      4    selenagomez               93  1800.0  342700000.0  6200000.0
#
#     60_day_eng_rate  new_post_avg_like   total_likes        country
# 9              0.59          1500000.0  1.390000e+10         Canada
# 13             1.01          2300000.0  1.300000e+09  United States
# 1              1.62          5900000.0  5.740000e+10  United States
# 5              0.88          2900000.0  1.990000e+10  United States
# 4              0.20           665300.0  1.250000e+10  United States
# 6              1.20          3900000.0  1.840000e+10  United States
# 20             0.16           265100.0  1.500000e+09            NaN
# 7              0.76          2000000.0  7.400000e+09  United States
# 0              1.39          6500000.0  2.900000e+10          Spain
# 3              0.97          3300000.0  1.150000e+10  United States

# %%
data.shape
# Out:
# (200, 10)

# %%
data.isnull().sum()
# Out:
# rank                  0
# account_name          0
# influence_score       0
# posts                 0
# followers             0
# avg_likes             0
# 60_day_eng_rate       1
# new_post_avg_like     0
# total_likes           0
# country              62
# dtype: int64

# %%
data.columns
# Out:
# Index(['rank', 'account_name', 'influence_score', 'posts', 'followers',
#        'avg_likes', '60_day_eng_rate', 'new_post_avg_like', 'total_likes',
#        'country'],
#       dtype='object')

# %%
data.set_index('rank')
# Out:
#       account_name  influence_score   posts    followers  avg_likes  \
# rank
# 94         mosalah               22   840.0   52500000.0  1800000.0
# 194         zidane               41   370.0   33500000.0  1100000.0
# 77    karimbenzema               42  2000.0   56900000.0   878500.0
# 128          maisa               42  1500.0   44500000.0   553000.0
# 175   nattinatasha               47    30.0   35900000.0   518100.0
# ...            ...              ...     ...          ...        ...
# 7     arianagrande               92  5000.0  327700000.0  3700000.0
# 21       katyperry               92  2000.0  170300000.0   715000.0
# 8          beyonce               92  2000.0  272800000.0  3600000.0
# 1        cristiano               92  3300.0  475800000.0  8700000.0
# 4      selenagomez               93  1800.0  342700000.0  6200000.0
#
#       60_day_eng_rate  new_post_avg_like   total_likes         country
# rank
# 94               2.18          1100000.0  1.500000e+09             NaN
# 194              1.61           532700.0  3.919000e+08          France
# 77               1.62           918900.0  1.800000e+09           Spain
# 128              0.67           294100.0  8.201000e+08          Brazil
# 175              0.80           285900.0  1.870000e+07  Czech Republic
# ...               ...                ...           ...             ...
# 7                1.20          3900000.0  1.840000e+10   United States
# 21               0.16           265100.0  1.500000e+09             NaN
# 8                0.76          2000000.0  7.400000e+09   United States
# 1                1.39          6500000.0  2.900000e+10           Spain
# 4                0.97          3300000.0  1.150000e+10   United States
#
# [200 rows x 9 columns]

# %%
top_inf = data.groupby('country')[['account_name', 'influence_score']].apply(lambda x: x.nlargest(1, 'influence_score')).reset_index(drop=True)
top_inf
# Out:
#            account_name  influence_score
# 0            norafatehi               83
# 1        chrishemsworth               86
# 2              neymarjr               90
# 3          mercedesbenz               77
# 4          justinbieber               91
# 5      jamesrodriguez10               86
# 6          nattinatasha               47
# 7         hrithikroshan               85
# 8                   psg               86
# 9                   bmw               79
# 10       jacquelinef143               85
# 11        ayutingting92               85
# 12                gucci               86
# 13      kimberly.loaiza               78
# 14        champagnepapi               85
# 15          daddyyankee               80
# 16  khabib_nurmagomedov               63
# 17            cristiano               92
# 18                   hm               83
# 19         ranveersingh               85
# 20               marvel               82
# 21              nusr_et               81
# 22     manchesterunited               85
# 23          selenagomez               93
# 24   bts.bighitofficial               78

# %%
avg = data.groupby('country')[['followers', 'avg_likes', 'total_likes']].mean().reset_index()
avg
# Out:
#                    country     followers     avg_likes   total_likes
# 0                 Anguilla  4.160000e+07  1.400000e+06  2.300000e+09
# 1                Australia  5.590000e+07  2.800000e+06  2.500000e+09
# 2                   Brazil  5.660769e+07  8.351846e+05  3.151485e+09
# 3   British Virgin Islands  3.600000e+07  1.979000e+05  2.000000e+09
# 4                   Canada  1.193333e+08  2.466667e+06  8.500000e+09
# 5                 Colombia  5.203333e+07  9.938667e+05  5.033333e+09
# 6           Czech Republic  3.590000e+07  5.181000e+05  1.870000e+07
# 7           C̫te d'Ivoire  4.370000e+07  1.600000e+06  9.499000e+08
# 8                   France  4.483333e+07  7.697333e+05  1.745217e+09
# 9                  Germany  3.370000e+07  2.313000e+05  2.200000e+09
# 10                   India  5.645000e+07  1.538492e+06  2.743250e+09
# 11               Indonesia  4.475714e+07  2.241714e+05  2.023671e+09
# 12                   Italy  4.900000e+07  1.151000e+05  1.000000e+09
# 13                  Mexico  3.510000e+07  2.050000e+06  2.200000e+09
# 14             Netherlands  8.540000e+07  1.281600e+06  8.950000e+09
# 15             Puerto Rico  4.590000e+07  6.525000e+05  1.830000e+07
# 16                  Russia  3.350000e+07  6.851000e+05  3.100000e+09
# 17                   Spain  1.478600e+08  2.178120e+06  7.736240e+09
# 18                  Sweden  3.850000e+07  8.840000e+04  6.441000e+08
# 19             Switzerland  4.080000e+07  1.000000e+06  1.800000e+09
# 20                  Turkey  5.415000e+07  4.227000e+05  1.950000e+09
# 21    United Arab Emirates  4.730000e+07  7.282000e+05  1.700000e+09
# 22          United Kingdom  5.987500e+07  9.821250e+05  3.375000e+09
# 23           United States  1.082985e+08  1.873545e+06  5.293220e+09
# 24                 Uruguay  6.690000e+07  4.100000e+06  4.900000e+09

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['influence_score'], kde=True, color='skyblue')
plt.title('Distribution of Influencer Scores')
plt.xlabel('Influencer Score')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_data, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Columns')
plt.show()

# %%
country= data['country'].value_counts()[:20].to_list()
name_countries = data['country'].value_counts().index[:20].to_list()

name_countries.append("Others")
max20 = sum(country)
others = len(data) - max20

country.append(others)

plt.figure(figsize=(10, 8))
sns.barplot(x=country, y=name_countries, palette='viridis')
plt.title('Distribution of Influencers by Country')
plt.xlabel('Number of Influencers')
plt.ylabel('Country')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='country', y='influence_score', data=data, palette='pastel')
plt.title('Country-wise Influence Score')
plt.xlabel('Country')
plt.ylabel('Influence Score')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.pairplot(data[['followers', 'total_likes', 'posts', 'avg_likes']])
plt.suptitle('Relationships Between Numerical Variables', y=1.02)
plt.show()
# Out:
# C:\Users\mridu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='followers', y='60_day_eng_rate', data=data)
plt.title('Relationship between Followers and 60-Day Engagement Rate')
plt.xlabel('Followers')
plt.ylabel('60-Day Engagement Rate')
plt.show()
